# %%
# !pip install pandas numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv', parse_dates=['timestamp'])

# %%
print(df.head())
# Out:
#             timestamp patient_id  age  cobb_angle_initial growth_stage  \
# 0 2025-11-02 06:00:00       P001   14                  32     pubertal
# 1 2025-11-02 06:15:00       P001   14                  32     pubertal
# 2 2025-11-02 06:30:00       P001   14                  32     pubertal
# 3 2025-11-02 06:45:00       P001   14                  32     pubertal
# 4 2025-11-02 07:00:00       P001   14                  32     pubertal
#
#    target_pressure_mmhg  target_posture_angle_deg  posture_angle_deg  \
# 0                  12.0                       8.0               14.0
# 1                  12.0                       8.0               10.8
# 2                  12.0                       8.0               15.3
# 3                  12.0                       8.0               14.5
# 4                  12.0                       8.0               15.0
#
#    brace_pressure_mmhg  emg_level_mv  skin_temp_c activity  \
# 0                 13.5          1.67         36.5  sitting
# ...

# %%
print(df.select_dtypes(include='number').describe())
# Out:
#         age  cobb_angle_initial  target_pressure_mmhg  \
# count  64.0                64.0                  64.0
# mean   14.0                32.0                  12.0
# std     0.0                 0.0                   0.0
# min    14.0                32.0                  12.0
# 25%    14.0                32.0                  12.0
# 50%    14.0                32.0                  12.0
# 75%    14.0                32.0                  12.0
# max    14.0                32.0                  12.0
#
#        target_posture_angle_deg  posture_angle_deg  brace_pressure_mmhg  \
# count                      64.0          64.000000            64.000000
# mean                        8.0          10.912500            12.734375
# std                         0.0           3.703045             1.334668
# min                         8.0           3.800000             9.300000
# 25%                         8.0           7.375000            11.950000
# ...

# %%
plt.figure(figsize=(10,4))
plt.plot(df['timestamp'], df['posture_angle_deg'], label='Posture Angle')
plt.plot(df['timestamp'], df['target_posture_angle_deg'], label='Target Angle', linestyle='--')
plt.xticks(rotation=45)
plt.ylabel('Degrees')
plt.title('Posture vs Target Across the Day')
plt.legend()
plt.tight_layout()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['timestamp'], df['brace_pressure_mmhg'], label='Brace Pressure')
plt.plot(df['timestamp'], df['target_pressure_mmhg'], label='Target Pressure', linestyle='--')
plt.xticks(rotation=45)
plt.ylabel('mmHg')
plt.title('Pressure vs Target Across the Day')
plt.legend()
plt.tight_layout()
